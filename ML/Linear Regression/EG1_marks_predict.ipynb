# %%
from sklearn.linear_model import LinearRegression

# %%
X = [[1],[2],[3],[4]]
y = [42,48,60,68]

model = LinearRegression()

model.fit(X,y)

pred = model.predict([[5]])

print("Predicted score: ", pred[0])
# Out:
# Predicted score:  77.0
